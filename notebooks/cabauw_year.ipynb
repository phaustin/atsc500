# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc" style="margin-top: 1em;"><ul class="toc-item"><li><span><a href="#Reading-multiple-months-from-the-cesar-archive" data-toc-modified-id="Reading-multiple-months-from-the-cesar-archive-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Reading multiple months from the cesar archive</a></span><ul class="toc-item"><li><span><a href="#Step-1:-read-in-all-the-file-names-and-return-a-dictionary" data-toc-modified-id="Step-1:-read-in-all-the-file-names-and-return-a-dictionary-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Step 1: read in all the file names and return a dictionary</a></span></li><li><span><a href="#Turn-cabauw-dates-into-datetime-objects" data-toc-modified-id="Turn-cabauw-dates-into-datetime-objects-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Turn cabauw dates into datetime objects</a></span></li><li><span><a href="#Extract-the-data" data-toc-modified-id="Extract-the-data-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Extract the data</a></span></li><li><span><a href="#Write-the-data-out-to-a-netcdf-file" data-toc-modified-id="Write-the-data-out-to-a-netcdf-file-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Write the data out to a netcdf file</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Reading multiple months from the cesar archive
#
# For this example I downloaded 12 months of data from 2014 with three file types
# (all lc1 i.e. gap-filled)
#
# cesar_surface_flux_lc1_t10_v1.0_201402.nc
#
# cesar_surface_meteo_lc1_t10_v1.0_201402.nc
#
# cesar_tower_meteo_lc1_t10_v1.0_201402.nc

# %% [markdown]
# ## Step 1: read in all the file names and return a dictionary
#
# The make_file_dict function returns a dictionary that contains three lists of file names keyed by:
#
#     ['surface_fluxes', 'surface_meteorological', 'tower_meteorological']

# %%
from a500.utils.read_cabauw import (make_file_dict,write_dates,
                                    store_months, write_cdf)
from pathlib import Path
root_dir = "/Users/phil/Downloads/data"
root_dir=Path(root_dir)
year = 2014
file_dict=make_file_dict(root_dir,year)

# %% [markdown]
# ## Turn cabauw dates into datetime objects
#
# The write_dates function opens each netcdf file and creates an dictionary with times, location and variable attributes keyed as:
#
#     [filetype](year,month]
#
#     i.e. ['surface_fluxes'][2014,4]

# %%
keep_months={}
for filetype,file_list in file_dict.items():
    keep_months[filetype]=write_dates(filetype,file_list)

# %% [markdown]
# ## Extract the data
#
# The store_months function takes the keep_months dictionary and
# returns a new dictionary with these keys for each of the three cabauw data files:
#
#     list(full_dict['surface_fluxes'].keys())
#     ['filelist', 'data', 'var_attrs', 'lat', 'lon']
#
# where filelist points to a list of the 12 filenames, data points to the data dictionary:
#
#     list(full_dict['surface_fluxes']['data'].keys())
#
#     [(2014, 1),
#      (2014, 2),
#      (2014, 3),
#      (2014, 4),
#      (2014, 5),
#      (2014, 6),
#      (2014, 7),
#      (2014, 8),
#      (2014, 9),
#      (2014, 10),
#      (2014, 11),
#      (2014, 12)]
#
#     list(full_dict['surface_fluxes']['data'][2014,1].keys())
#     ['H', 'UST', 'LE']
#
#     list(full_dict['surface_meteorological']['data'][2014,1].keys())
#     ['P0', 'TA002', 'Q002', 'F010']
#
#     list(full_dict['tower_meteorological']['data'][2014,1].keys())
#     ['timevec', 'has_time', 'z', 'F', 'TA', 'TD', 'Q', 'D']
#
# and var_attrs list the variable attributes
#
#     list(full_dict['tower_meteorological']['var_attrs']['F'].keys())
#
#         ['units',
#      'long_name',
#      'standard_name',
#      'ancillary_variables',
#      '_FillValue',
#      'cell_methods']

# %%
full_dict=store_months(keep_months)
# Out:
# working on surface_fluxes: 2014-01-01 00:00:00+00:00
# working on surface_fluxes: 2014-02-01 00:00:00+00:00
# working on surface_fluxes: 2014-03-01 00:00:00+00:00
# working on surface_fluxes: 2014-04-01 00:00:00+00:00
# working on surface_fluxes: 2014-05-01 00:00:00+00:00
# working on surface_fluxes: 2014-06-01 00:00:00+00:00
# working on surface_fluxes: 2014-07-01 00:00:00+00:00
# working on surface_fluxes: 2014-08-01 00:00:00+00:00
# working on surface_fluxes: 2014-09-01 00:00:00+00:00
# working on surface_fluxes: 2014-10-01 00:00:00+00:00
# working on surface_fluxes: 2014-11-01 00:00:00+00:00
# working on surface_fluxes: 2014-12-01 00:00:00+00:00
# working on surface_meteorological: 2014-01-01 00:00:00+00:00
# working on surface_meteorological: 2014-02-01 00:00:00+00:00
# working on surface_meteorological: 2014-03-01 00:00:00+00:00
# working on surface_meteorological: 2014-04-01 00:00:00+00:00
# working on surface_meteorological: 2014-05-01 00:00:00+00:00
# working on surface_meteorological: 2014-06-01 00:00:00+00:00
# working on surface_meteorological: 2014-07-01 00:00:00+00:00
# working on surface_meteorological: 2014-08-01 00:00:00+00:00
# working on surface_meteorological: 2014-09-01 00:00:00+00:00
# working on surface_meteorological: 2014-10-01 00:00:00+00:00
# working on surface_meteorological: 2014-11-01 00:00:00+00:00
# working on surface_meteorological: 2014-12-01 00:00:00+00:00
# working on tower_meteorological: 2014-01-01 00:00:00+00:00
# working on tower_meteorological: 2014-02-01 00:00:00+00:00
# working on tower_meteorological: 2014-03-01 00:00:00+00:00
# working on tower_meteorological: 2014-04-01 00:00:00+00:00
# working on tower_meteorological: 2014-05-01 00:00:00+00:00
# working on tower_meteorological: 2014-06-01 00:00:00+00:00
# working on tower_meteorological: 2014-07-01 00:00:00+00:00
# working on tower_meteorological: 2014-08-01 00:00:00+00:00
# working on tower_meteorological: 2014-09-01 00:00:00+00:00
# working on tower_meteorological: 2014-10-01 00:00:00+00:00
# working on tower_meteorological: 2014-11-01 00:00:00+00:00
# working on tower_meteorological: 2014-12-01 00:00:00+00:00

# %% [markdown]
# ## Write the data out to a netcdf file
#
# write_cdf takes the dictionary and produces a netcdf file with
# the following metadata:

# %%
write_cdf(full_dict,'cabau_2014.nc')

# %%
# !ncdump -h cabau_2014.nc
# Out:
# netcdf cabau_2014 {
# dimensions:
# 	days31 = 31 ;
# 	hours = 24 ;
# 	min10 = 6 ;
# 	z = 7 ;
# 	days28 = 28 ;
# 	days30 = 30 ;
# variables:
# 	float z(z) ;
#
# // global attributes:
# 		:history = "written by read_cabauw.ipynb" ;
# 		:lat = 51.97 ;
# 		:lon = 4.926 ;
# 		:lat_units = "degrees north" ;
# 		:lon_units = "degrees east" ;
# 		:surface_fluxes_filelist = "cesar_surface_flux_lc1_t10_v1.0_201401.nc,cesar_surface_flux_lc1_t10_v1.0_201402.nc,cesar_surface_flux_lc1_t10_v1.0_201403.nc,cesar_surface_flux_lc1_t10_v1.0_201404.nc,cesar_surface_flux_lc1_t10_v1.0_201405.nc,cesar_surface_flux_lc1_t10_v1.0_201406.nc,cesar_surface_flux_lc1_t10_v1.0_201407.nc,cesar_surface_flux_lc1_t10_v1.0_201408.nc,cesar_surface_flux_lc1_t10_v1.0_201409.nc,cesar_surface_flux_lc1_t10_v1.0_201410.nc,cesar_surface_flux_lc1_t10_v1.0_201411.nc,cesar_surface_flux_lc1_t10_v1.0_201412.nc" ;
# 		:surface_meteorological_filelist = "cesar_surface_meteo_lc1_t10_v1.0_201401.nc,cesar_surface_meteo_lc1_t10_v1.0_201402.nc,cesar_surface_meteo_lc1_t10_v1.0_201403.nc,cesar_surface_meteo_lc1_t10_v1.0_201404.nc,cesar_surface_meteo_lc1_t10_v1.0_201405.nc,cesar_surface_meteo_lc1_t10_v1.0_201406.nc,cesar_surface_meteo_lc1_t10_v1.0_201407.nc,cesar_surface_meteo_lc1_t10_v1.0_201408.nc,cesar_surface_meteo_lc1_t10_v1.0_201409.nc,cesar_surface_meteo_lc1_t10_v1.0_201410.nc,cesar_surface_meteo_lc1_t10_v1.0_201411.nc,cesar_surface_meteo_lc1_t10_v1.0_201412.nc" ;
# 		:tower_meteorological_filelist = "cesar_tower_meteo_lc1_t10_v1.0_201401.nc,cesar_tower_meteo_lc1_t10_v1.0_201402.nc,cesar_tower_meteo_lc1_t10_v1.0_201403.nc,cesar_tower_meteo_lc1_t10_v1.0_201404.nc,cesar_tower_meteo_lc1_t10_v1.0_201405.nc,cesar_tower_meteo_lc1_t10_v1.0_201406.nc,cesar_tower_meteo_lc1_t10_v1.0_201407.nc,cesar_tower_meteo_lc1_t10_v1.0_201408.nc,cesar_tower_meteo_lc1_t10_v1.0_201409.nc,cesar_tower_meteo_lc1_t10_v1.0_201410.nc,cesar_tower_meteo_lc1_t10_v1.0_201411.nc,cesar_tower_meteo_lc1_t10_v1.0_201412.nc" ;
#
# group: m2014_01 {
#   variables:
#   	float H(days31, hours, min10) ;
#   		H:units = "W m-2" ;
#   		H:long_name = "MERGED Surface sensible heat flux" ;
#   		H:standard_name = "surface_upward_sensible_heat_flux" ;
#   		H:accuracy = "10%" ;
#   		H:ancillary_variables = "IH" ;
#   		H:cell_methods = "time: mean" ;
#   	float LE(days31, hours, min10) ;
#   		LE:units = "W m-2" ;
#   		LE:long_name = "MERGED Surface latent heat flux" ;
#   		LE:standard_name = "surface_upward_latent_heat_flux" ;
#   		LE:accuracy = "10%" ;
#   		LE:ancillary_variables = "ILE" ;
#   		LE:cell_methods = "time: mean" ;
#   	float UST(days31, hours, min10) ;
#   		UST:units = "m s-1" ;
#   		UST:long_name = "MERGED Friction velocity" ;
#   		UST:ancillary_variables = "IUST" ;
#   		UST:cell_methods = "time: mean" ;
#   	float P0(days31, hours, min10) ;
#   		P0:units = "hPa" ;
#   		P0:long_name = "MERGED Atmospheric air pressure" ;
#   		P0:standard_name = "air_pressure_at_sensor_level" ;
#   		P0:accuracy = "0.1" ;
#   		P0:ancillary_variables = "IP0" ;
#   		P0:cell_methods = "time: mean" ;
#   	float TA002(days31, hours, min10) ;
#   		TA002:units = "degC" ;
#   		TA002:long_name = "MERGED Air temperature at   2 m" ;
#   		TA002:standard_name = "air_temperature" ;
#   		TA002:accuracy = "0.1" ;
#   		TA002:ancillary_variables = "ITA002" ;
#   		TA002:cell_methods = "time: mean" ;
#   	float Q002(days31, hours, min10) ;
#   		Q002:units = "1e-3" ;
#   		Q002:long_name = "MERGED Specific humidity     at   2 m" ;
#   		Q002:ancillary_variables = "IQ002" ;
#   		Q002:cell_methods = "time: mean" ;
#   	float F010(days31, hours, min10) ;
#   		F010:units = "m s-1" ;
#   		F010:long_name = "MERGED Wind speed at  10 m" ;
#   		F010:standard_name = "wind_speed" ;
#   		F010:accuracy = "0.5" ;
#   		F010:ancillary_variables = "IF010" ;
#   		F010:cell_methods = "time: mean" ;
#   	float TA(days31, hours, min10, z) ;
#   		TA:units = "K" ;
#   		TA:long_name = "MERGED Air temperature" ;
#   		TA:standard_name = "air_temperature" ;
#   		TA:ancillary_variables = "ITA" ;
#   		TA:cell_methods = "time: mean" ;
#   	float D(days31, hours, min10, z) ;
#   		D:units = "degree" ;
#   		D:long_name = "MERGED Wind direction" ;
#   		D:standard_name = "wind_from_direction" ;
#   		D:ancillary_variables = "ID" ;
#   		D:cell_methods = "time: mean" ;
#   	float Q(days31, hours, min10, z) ;
#   		Q:units = "1e-3" ;
#   		Q:long_name = "MERGED Specific humidity" ;
#   		Q:ancillary_variables = "IQ" ;
#   		Q:cell_methods = "time: mean" ;
#   	float TD(days31, hours, min10, z) ;
#   		TD:units = "K" ;
#   		TD:long_name = "Dew point temperature from MERGED Spec. hum." ;
#   		TD:standard_name = "dew_point_temperature" ;
#   		TD:cell_methods = "time: mean" ;
#   	float F(days31, hours, min10, z) ;
#   		F:units = "m s-1" ;
#   		F:long_name = "MERGED Wind speed" ;
#   		F:standard_name = "wind_speed" ;
#   		F:ancillary_variables = "IF" ;
#   		F:cell_methods = "time: mean" ;
#   	double time(days31, hours, min10) ;
#   		time:timezone = "UTC" ;
#   		time:comment = "convert using datetime.fromtimestamp(var,pytz.utc)" ;
#
#   // group attributes:
#   		:month = 2014, 1 ;
#   } // group m2014_01
#
# group: m2014_02 {
#   variables:
#   	float H(days28, hours, min10) ;
#   		H:units = "W m-2" ;
#   		H:long_name = "MERGED Surface sensible heat flux" ;
#   		H:standard_name = "surface_upward_sensible_heat_flux" ;
#   		H:accuracy = "10%" ;
#   		H:ancillary_variables = "IH" ;
#   		H:cell_methods = "time: mean" ;
#   	float LE(days28, hours, min10) ;
#   		LE:units = "W m-2" ;
#   		LE:long_name = "MERGED Surface latent heat flux" ;
#   		LE:standard_name = "surface_upward_latent_heat_flux" ;
#   		LE:accuracy = "10%" ;
#   		LE:ancillary_variables = "ILE" ;
#   		LE:cell_methods = "time: mean" ;
#   	float UST(days28, hours, min10) ;
#   		UST:units = "m s-1" ;
#   		UST:long_name = "MERGED Friction velocity" ;
#   		UST:ancillary_variables = "IUST" ;
#   		UST:cell_methods = "time: mean" ;
#   	float P0(days28, hours, min10) ;
#   		P0:units = "hPa" ;
#   		P0:long_name = "MERGED Atmospheric air pressure" ;
#   		P0:standard_name = "air_pressure_at_sensor_level" ;
#   		P0:accuracy = "0.1" ;
#   		P0:ancillary_variables = "IP0" ;
#   		P0:cell_methods = "time: mean" ;
#   	float TA002(days28, hours, min10) ;
#   		TA002:units = "degC" ;
#   		TA002:long_name = "MERGED Air temperature at   2 m" ;
#   		TA002:standard_name = "air_temperature" ;
#   		TA002:accuracy = "0.1" ;
#   		TA002:ancillary_variables = "ITA002" ;
#   		TA002:cell_methods = "time: mean" ;
#   	float Q002(days28, hours, min10) ;
#   		Q002:units = "1e-3" ;
#   		Q002:long_name = "MERGED Specific humidity     at   2 m" ;
#   		Q002:ancillary_variables = "IQ002" ;
#   		Q002:cell_methods = "time: mean" ;
#   	float F010(days28, hours, min10) ;
#   		F010:units = "m s-1" ;
#   		F010:long_name = "MERGED Wind speed at  10 m" ;
#   		F010:standard_name = "wind_speed" ;
#   		F010:accuracy = "0.5" ;
#   		F010:ancillary_variables = "IF010" ;
#   		F010:cell_methods = "time: mean" ;
#   	float TA(days28, hours, min10, z) ;
#   		TA:units = "K" ;
#   		TA:long_name = "MERGED Air temperature" ;
#   		TA:standard_name = "air_temperature" ;
#   		TA:ancillary_variables = "ITA" ;
#   		TA:cell_methods = "time: mean" ;
#   	float D(days28, hours, min10, z) ;
#   		D:units = "degree" ;
#   		D:long_name = "MERGED Wind direction" ;
#   		D:standard_name = "wind_from_direction" ;
#   		D:ancillary_variables = "ID" ;
#   		D:cell_methods = "time: mean" ;
#   	float Q(days28, hours, min10, z) ;
#   		Q:units = "1e-3" ;
#   		Q:long_name = "MERGED Specific humidity" ;
#   		Q:ancillary_variables = "IQ" ;
#   		Q:cell_methods = "time: mean" ;
#   	float TD(days28, hours, min10, z) ;
#   		TD:units = "K" ;
#   		TD:long_name = "Dew point temperature from MERGED Spec. hum." ;
#   		TD:standard_name = "dew_point_temperature" ;
#   		TD:cell_methods = "time: mean" ;
#   	float F(days28, hours, min10, z) ;
#   		F:units = "m s-1" ;
#   		F:long_name = "MERGED Wind speed" ;
#   		F:standard_name = "wind_speed" ;
#   		F:ancillary_variables = "IF" ;
#   		F:cell_methods = "time: mean" ;
#   	double time(days28, hours, min10) ;
#   		time:timezone = "UTC" ;
#   		time:comment = "convert using datetime.fromtimestamp(var,pytz.utc)" ;
#
#   // group attributes:
#   		:month = 2014, 2 ;
#   } // group m2014_02
#
# group: m2014_03 {
#   variables:
#   	float H(days31, hours, min10) ;
#   		H:units = "W m-2" ;
#   		H:long_name = "MERGED Surface sensible heat flux" ;
#   		H:standard_name = "surface_upward_sensible_heat_flux" ;
#   		H:accuracy = "10%" ;
#   		H:ancillary_variables = "IH" ;
#   		H:cell_methods = "time: mean" ;
#   	float LE(days31, hours, min10) ;
#   		LE:units = "W m-2" ;
#   		LE:long_name = "MERGED Surface latent heat flux" ;
#   		LE:standard_name = "surface_upward_latent_heat_flux" ;
#   		LE:accuracy = "10%" ;
#   		LE:ancillary_variables = "ILE" ;
#   		LE:cell_methods = "time: mean" ;
#   	float UST(days31, hours, min10) ;
#   		UST:units = "m s-1" ;
#   		UST:long_name = "MERGED Friction velocity" ;
#   		UST:ancillary_variables = "IUST" ;
#   		UST:cell_methods = "time: mean" ;
#   	float P0(days31, hours, min10) ;
#   		P0:units = "hPa" ;
#   		P0:long_name = "MERGED Atmospheric air pressure" ;
#   		P0:standard_name = "air_pressure_at_sensor_level" ;
#   		P0:accuracy = "0.1" ;
#   		P0:ancillary_variables = "IP0" ;
#   		P0:cell_methods = "time: mean" ;
#   	float TA002(days31, hours, min10) ;
#   		TA002:units = "degC" ;
#   		TA002:long_name = "MERGED Air temperature at   2 m" ;
#   		TA002:standard_name = "air_temperature" ;
#   		TA002:accuracy = "0.1" ;
#   		TA002:ancillary_variables = "ITA002" ;
#   		TA002:cell_methods = "time: mean" ;
#   	float Q002(days31, hours, min10) ;
#   		Q002:units = "1e-3" ;
#   		Q002:long_name = "MERGED Specific humidity     at   2 m" ;
#   		Q002:ancillary_variables = "IQ002" ;
#   		Q002:cell_methods = "time: mean" ;
#   	float F010(days31, hours, min10) ;
#   		F010:units = "m s-1" ;
#   		F010:long_name = "MERGED Wind speed at  10 m" ;
#   		F010:standard_name = "wind_speed" ;
#   		F010:accuracy = "0.5" ;
#   		F010:ancillary_variables = "IF010" ;
#   		F010:cell_methods = "time: mean" ;
#   	float TA(days31, hours, min10, z) ;
#   		TA:units = "K" ;
#   		TA:long_name = "MERGED Air temperature" ;
#   		TA:standard_name = "air_temperature" ;
#   		TA:ancillary_variables = "ITA" ;
#   		TA:cell_methods = "time: mean" ;
#   	float D(days31, hours, min10, z) ;
#   		D:units = "degree" ;
#   		D:long_name = "MERGED Wind direction" ;
#   		D:standard_name = "wind_from_direction" ;
#   		D:ancillary_variables = "ID" ;
#   		D:cell_methods = "time: mean" ;
#   	float Q(days31, hours, min10, z) ;
#   		Q:units = "1e-3" ;
#   		Q:long_name = "MERGED Specific humidity" ;
#   		Q:ancillary_variables = "IQ" ;
#   		Q:cell_methods = "time: mean" ;
#   	float TD(days31, hours, min10, z) ;
#   		TD:units = "K" ;
#   		TD:long_name = "Dew point temperature from MERGED Spec. hum." ;
#   		TD:standard_name = "dew_point_temperature" ;
#   		TD:cell_methods = "time: mean" ;
#   	float F(days31, hours, min10, z) ;
#   		F:units = "m s-1" ;
#   		F:long_name = "MERGED Wind speed" ;
#   		F:standard_name = "wind_speed" ;
#   		F:ancillary_variables = "IF" ;
#   		F:cell_methods = "time: mean" ;
#   	double time(days31, hours, min10) ;
#   		time:timezone = "UTC" ;
#   		time:comment = "convert using datetime.fromtimestamp(var,pytz.utc)" ;
#
#   // group attributes:
#   		:month = 2014, 3 ;
#   } // group m2014_03
#
# group: m2014_04 {
#   variables:
#   	float H(days30, hours, min10) ;
#   		H:units = "W m-2" ;
#   		H:long_name = "MERGED Surface sensible heat flux" ;
#   		H:standard_name = "surface_upward_sensible_heat_flux" ;
#   		H:accuracy = "10%" ;
#   		H:ancillary_variables = "IH" ;
#   		H:cell_methods = "time: mean" ;
#   	float LE(days30, hours, min10) ;
#   		LE:units = "W m-2" ;
#   		LE:long_name = "MERGED Surface latent heat flux" ;
#   		LE:standard_name = "surface_upward_latent_heat_flux" ;
#   		LE:accuracy = "10%" ;
#   		LE:ancillary_variables = "ILE" ;
#   		LE:cell_methods = "time: mean" ;
#   	float UST(days30, hours, min10) ;
#   		UST:units = "m s-1" ;
#   		UST:long_name = "MERGED Friction velocity" ;
#   		UST:ancillary_variables = "IUST" ;
#   		UST:cell_methods = "time: mean" ;
#   	float P0(days30, hours, min10) ;
#   		P0:units = "hPa" ;
#   		P0:long_name = "MERGED Atmospheric air pressure" ;
#   		P0:standard_name = "air_pressure_at_sensor_level" ;
#   		P0:accuracy = "0.1" ;
#   		P0:ancillary_variables = "IP0" ;
#   		P0:cell_methods = "time: mean" ;
#   	float TA002(days30, hours, min10) ;
#   		TA002:units = "degC" ;
#   		TA002:long_name = "MERGED Air temperature at   2 m" ;
#   		TA002:standard_name = "air_temperature" ;
#   		TA002:accuracy = "0.1" ;
#   		TA002:ancillary_variables = "ITA002" ;
#   		TA002:cell_methods = "time: mean" ;
#   	float Q002(days30, hours, min10) ;
#   		Q002:units = "1e-3" ;
#   		Q002:long_name = "MERGED Specific humidity     at   2 m" ;
#   		Q002:ancillary_variables = "IQ002" ;
#   		Q002:cell_methods = "time: mean" ;
#   	float F010(days30, hours, min10) ;
#   		F010:units = "m s-1" ;
#   		F010:long_name = "MERGED Wind speed at  10 m" ;
#   		F010:standard_name = "wind_speed" ;
#   		F010:accuracy = "0.5" ;
#   		F010:ancillary_variables = "IF010" ;
#   		F010:cell_methods = "time: mean" ;
#   	float TA(days30, hours, min10, z) ;
#   		TA:units = "K" ;
#   		TA:long_name = "MERGED Air temperature" ;
#   		TA:standard_name = "air_temperature" ;
#   		TA:ancillary_variables = "ITA" ;
#   		TA:cell_methods = "time: mean" ;
#   	float D(days30, hours, min10, z) ;
#   		D:units = "degree" ;
#   		D:long_name = "MERGED Wind direction" ;
#   		D:standard_name = "wind_from_direction" ;
#   		D:ancillary_variables = "ID" ;
#   		D:cell_methods = "time: mean" ;
#   	float Q(days30, hours, min10, z) ;
#   		Q:units = "1e-3" ;
#   		Q:long_name = "MERGED Specific humidity" ;
#   		Q:ancillary_variables = "IQ" ;
#   		Q:cell_methods = "time: mean" ;
#   	float TD(days30, hours, min10, z) ;
#   		TD:units = "K" ;
#   		TD:long_name = "Dew point temperature from MERGED Spec. hum." ;
#   		TD:standard_name = "dew_point_temperature" ;
#   		TD:cell_methods = "time: mean" ;
#   	float F(days30, hours, min10, z) ;
#   		F:units = "m s-1" ;
#   		F:long_name = "MERGED Wind speed" ;
#   		F:standard_name = "wind_speed" ;
#   		F:ancillary_variables = "IF" ;
#   		F:cell_methods = "time: mean" ;
#   	double time(days30, hours, min10) ;
#   		time:timezone = "UTC" ;
#   		time:comment = "convert using datetime.fromtimestamp(var,pytz.utc)" ;
#
#   // group attributes:
#   		:month = 2014, 4 ;
#   } // group m2014_04
#
# group: m2014_05 {
#   variables:
#   	float H(days31, hours, min10) ;
#   		H:units = "W m-2" ;
#   		H:long_name = "MERGED Surface sensible heat flux" ;
#   		H:standard_name = "surface_upward_sensible_heat_flux" ;
#   		H:accuracy = "10%" ;
#   		H:ancillary_variables = "IH" ;
#   		H:cell_methods = "time: mean" ;
#   	float LE(days31, hours, min10) ;
#   		LE:units = "W m-2" ;
#   		LE:long_name = "MERGED Surface latent heat flux" ;
#   		LE:standard_name = "surface_upward_latent_heat_flux" ;
#   		LE:accuracy = "10%" ;
#   		LE:ancillary_variables = "ILE" ;
#   		LE:cell_methods = "time: mean" ;
#   	float UST(days31, hours, min10) ;
#   		UST:units = "m s-1" ;
#   		UST:long_name = "MERGED Friction velocity" ;
#   		UST:ancillary_variables = "IUST" ;
#   		UST:cell_methods = "time: mean" ;
#   	float P0(days31, hours, min10) ;
#   		P0:units = "hPa" ;
#   		P0:long_name = "MERGED Atmospheric air pressure" ;
#   		P0:standard_name = "air_pressure_at_sensor_level" ;
#   		P0:accuracy = "0.1" ;
#   		P0:ancillary_variables = "IP0" ;
#   		P0:cell_methods = "time: mean" ;
#   	float TA002(days31, hours, min10) ;
#   		TA002:units = "degC" ;
#   		TA002:long_name = "MERGED Air temperature at   2 m" ;
#   		TA002:standard_name = "air_temperature" ;
#   		TA002:accuracy = "0.1" ;
#   		TA002:ancillary_variables = "ITA002" ;
#   		TA002:cell_methods = "time: mean" ;
#   	float Q002(days31, hours, min10) ;
#   		Q002:units = "1e-3" ;
#   		Q002:long_name = "MERGED Specific humidity     at   2 m" ;
#   		Q002:ancillary_variables = "IQ002" ;
#   		Q002:cell_methods = "time: mean" ;
#   	float F010(days31, hours, min10) ;
#   		F010:units = "m s-1" ;
#   		F010:long_name = "MERGED Wind speed at  10 m" ;
#   		F010:standard_name = "wind_speed" ;
#   		F010:accuracy = "0.5" ;
#   		F010:ancillary_variables = "IF010" ;
#   		F010:cell_methods = "time: mean" ;
#   	float TA(days31, hours, min10, z) ;
#   		TA:units = "K" ;
#   		TA:long_name = "MERGED Air temperature" ;
#   		TA:standard_name = "air_temperature" ;
#   		TA:ancillary_variables = "ITA" ;
#   		TA:cell_methods = "time: mean" ;
#   	float D(days31, hours, min10, z) ;
#   		D:units = "degree" ;
#   		D:long_name = "MERGED Wind direction" ;
#   		D:standard_name = "wind_from_direction" ;
#   		D:ancillary_variables = "ID" ;
#   		D:cell_methods = "time: mean" ;
#   	float Q(days31, hours, min10, z) ;
#   		Q:units = "1e-3" ;
#   		Q:long_name = "MERGED Specific humidity" ;
#   		Q:ancillary_variables = "IQ" ;
#   		Q:cell_methods = "time: mean" ;
#   	float TD(days31, hours, min10, z) ;
#   		TD:units = "K" ;
#   		TD:long_name = "Dew point temperature from MERGED Spec. hum." ;
#   		TD:standard_name = "dew_point_temperature" ;
#   		TD:cell_methods = "time: mean" ;
#   	float F(days31, hours, min10, z) ;
#   		F:units = "m s-1" ;
#   		F:long_name = "MERGED Wind speed" ;
#   		F:standard_name = "wind_speed" ;
#   		F:ancillary_variables = "IF" ;
#   		F:cell_methods = "time: mean" ;
#   	double time(days31, hours, min10) ;
#   		time:timezone = "UTC" ;
#   		time:comment = "convert using datetime.fromtimestamp(var,pytz.utc)" ;
#
#   // group attributes:
#   		:month = 2014, 5 ;
#   } // group m2014_05
#
# group: m2014_06 {
#   variables:
#   	float H(days30, hours, min10) ;
#   		H:units = "W m-2" ;
#   		H:long_name = "MERGED Surface sensible heat flux" ;
#   		H:standard_name = "surface_upward_sensible_heat_flux" ;
#   		H:accuracy = "10%" ;
#   		H:ancillary_variables = "IH" ;
#   		H:cell_methods = "time: mean" ;
#   	float LE(days30, hours, min10) ;
#   		LE:units = "W m-2" ;
#   		LE:long_name = "MERGED Surface latent heat flux" ;
#   		LE:standard_name = "surface_upward_latent_heat_flux" ;
#   		LE:accuracy = "10%" ;
#   		LE:ancillary_variables = "ILE" ;
#   		LE:cell_methods = "time: mean" ;
#   	float UST(days30, hours, min10) ;
#   		UST:units = "m s-1" ;
#   		UST:long_name = "MERGED Friction velocity" ;
#   		UST:ancillary_variables = "IUST" ;
#   		UST:cell_methods = "time: mean" ;
#   	float P0(days30, hours, min10) ;
#   		P0:units = "hPa" ;
#   		P0:long_name = "MERGED Atmospheric air pressure" ;
#   		P0:standard_name = "air_pressure_at_sensor_level" ;
#   		P0:accuracy = "0.1" ;
#   		P0:ancillary_variables = "IP0" ;
#   		P0:cell_methods = "time: mean" ;
#   	float TA002(days30, hours, min10) ;
#   		TA002:units = "degC" ;
#   		TA002:long_name = "MERGED Air temperature at   2 m" ;
#   		TA002:standard_name = "air_temperature" ;
#   		TA002:accuracy = "0.1" ;
#   		TA002:ancillary_variables = "ITA002" ;
#   		TA002:cell_methods = "time: mean" ;
#   	float Q002(days30, hours, min10) ;
#   		Q002:units = "1e-3" ;
#   		Q002:long_name = "MERGED Specific humidity     at   2 m" ;
#   		Q002:ancillary_variables = "IQ002" ;
#   		Q002:cell_methods = "time: mean" ;
#   	float F010(days30, hours, min10) ;
#   		F010:units = "m s-1" ;
#   		F010:long_name = "MERGED Wind speed at  10 m" ;
#   		F010:standard_name = "wind_speed" ;
#   		F010:accuracy = "0.5" ;
#   		F010:ancillary_variables = "IF010" ;
#   		F010:cell_methods = "time: mean" ;
#   	float TA(days30, hours, min10, z) ;
#   		TA:units = "K" ;
#   		TA:long_name = "MERGED Air temperature" ;
#   		TA:standard_name = "air_temperature" ;
#   		TA:ancillary_variables = "ITA" ;
#   		TA:cell_methods = "time: mean" ;
#   	float D(days30, hours, min10, z) ;
#   		D:units = "degree" ;
#   		D:long_name = "MERGED Wind direction" ;
#   		D:standard_name = "wind_from_direction" ;
#   		D:ancillary_variables = "ID" ;
#   		D:cell_methods = "time: mean" ;
#   	float Q(days30, hours, min10, z) ;
#   		Q:units = "1e-3" ;
#   		Q:long_name = "MERGED Specific humidity" ;
#   		Q:ancillary_variables = "IQ" ;
#   		Q:cell_methods = "time: mean" ;
#   	float TD(days30, hours, min10, z) ;
#   		TD:units = "K" ;
#   		TD:long_name = "Dew point temperature from MERGED Spec. hum." ;
#   		TD:standard_name = "dew_point_temperature" ;
#   		TD:cell_methods = "time: mean" ;
#   	float F(days30, hours, min10, z) ;
#   		F:units = "m s-1" ;
#   		F:long_name = "MERGED Wind speed" ;
#   		F:standard_name = "wind_speed" ;
#   		F:ancillary_variables = "IF" ;
#   		F:cell_methods = "time: mean" ;
#   	double time(days30, hours, min10) ;
#   		time:timezone = "UTC" ;
#   		time:comment = "convert using datetime.fromtimestamp(var,pytz.utc)" ;
#
#   // group attributes:
#   		:month = 2014, 6 ;
#   } // group m2014_06
#
# group: m2014_07 {
#   variables:
#   	float H(days31, hours, min10) ;
#   		H:units = "W m-2" ;
#   		H:long_name = "MERGED Surface sensible heat flux" ;
#   		H:standard_name = "surface_upward_sensible_heat_flux" ;
#   		H:accuracy = "10%" ;
#   		H:ancillary_variables = "IH" ;
#   		H:cell_methods = "time: mean" ;
#   	float LE(days31, hours, min10) ;
#   		LE:units = "W m-2" ;
#   		LE:long_name = "MERGED Surface latent heat flux" ;
#   		LE:standard_name = "surface_upward_latent_heat_flux" ;
#   		LE:accuracy = "10%" ;
#   		LE:ancillary_variables = "ILE" ;
#   		LE:cell_methods = "time: mean" ;
#   	float UST(days31, hours, min10) ;
#   		UST:units = "m s-1" ;
#   		UST:long_name = "MERGED Friction velocity" ;
#   		UST:ancillary_variables = "IUST" ;
#   		UST:cell_methods = "time: mean" ;
#   	float P0(days31, hours, min10) ;
#   		P0:units = "hPa" ;
#   		P0:long_name = "MERGED Atmospheric air pressure" ;
#   		P0:standard_name = "air_pressure_at_sensor_level" ;
#   		P0:accuracy = "0.1" ;
#   		P0:ancillary_variables = "IP0" ;
#   		P0:cell_methods = "time: mean" ;
#   	float TA002(days31, hours, min10) ;
#   		TA002:units = "degC" ;
#   		TA002:long_name = "MERGED Air temperature at   2 m" ;
#   		TA002:standard_name = "air_temperature" ;
#   		TA002:accuracy = "0.1" ;
#   		TA002:ancillary_variables = "ITA002" ;
#   		TA002:cell_methods = "time: mean" ;
#   	float Q002(days31, hours, min10) ;
#   		Q002:units = "1e-3" ;
#   		Q002:long_name = "MERGED Specific humidity     at   2 m" ;
#   		Q002:ancillary_variables = "IQ002" ;
#   		Q002:cell_methods = "time: mean" ;
#   	float F010(days31, hours, min10) ;
#   		F010:units = "m s-1" ;
#   		F010:long_name = "MERGED Wind speed at  10 m" ;
#   		F010:standard_name = "wind_speed" ;
#   		F010:accuracy = "0.5" ;
#   		F010:ancillary_variables = "IF010" ;
#   		F010:cell_methods = "time: mean" ;
#   	float TA(days31, hours, min10, z) ;
#   		TA:units = "K" ;
#   		TA:long_name = "MERGED Air temperature" ;
#   		TA:standard_name = "air_temperature" ;
#   		TA:ancillary_variables = "ITA" ;
#   		TA:cell_methods = "time: mean" ;
#   	float D(days31, hours, min10, z) ;
#   		D:units = "degree" ;
#   		D:long_name = "MERGED Wind direction" ;
#   		D:standard_name = "wind_from_direction" ;
#   		D:ancillary_variables = "ID" ;
#   		D:cell_methods = "time: mean" ;
#   	float Q(days31, hours, min10, z) ;
#   		Q:units = "1e-3" ;
#   		Q:long_name = "MERGED Specific humidity" ;
#   		Q:ancillary_variables = "IQ" ;
#   		Q:cell_methods = "time: mean" ;
#   	float TD(days31, hours, min10, z) ;
#   		TD:units = "K" ;
#   		TD:long_name = "Dew point temperature from MERGED Spec. hum." ;
#   		TD:standard_name = "dew_point_temperature" ;
#   		TD:cell_methods = "time: mean" ;
#   	float F(days31, hours, min10, z) ;
#   		F:units = "m s-1" ;
#   		F:long_name = "MERGED Wind speed" ;
#   		F:standard_name = "wind_speed" ;
#   		F:ancillary_variables = "IF" ;
#   		F:cell_methods = "time: mean" ;
#   	double time(days31, hours, min10) ;
#   		time:timezone = "UTC" ;
#   		time:comment = "convert using datetime.fromtimestamp(var,pytz.utc)" ;
#
#   // group attributes:
#   		:month = 2014, 7 ;
#   } // group m2014_07
#
# group: m2014_08 {
#   variables:
#   	float H(days31, hours, min10) ;
#   		H:units = "W m-2" ;
#   		H:long_name = "MERGED Surface sensible heat flux" ;
#   		H:standard_name = "surface_upward_sensible_heat_flux" ;
#   		H:accuracy = "10%" ;
#   		H:ancillary_variables = "IH" ;
#   		H:cell_methods = "time: mean" ;
#   	float LE(days31, hours, min10) ;
#   		LE:units = "W m-2" ;
#   		LE:long_name = "MERGED Surface latent heat flux" ;
#   		LE:standard_name = "surface_upward_latent_heat_flux" ;
#   		LE:accuracy = "10%" ;
#   		LE:ancillary_variables = "ILE" ;
#   		LE:cell_methods = "time: mean" ;
#   	float UST(days31, hours, min10) ;
#   		UST:units = "m s-1" ;
#   		UST:long_name = "MERGED Friction velocity" ;
#   		UST:ancillary_variables = "IUST" ;
#   		UST:cell_methods = "time: mean" ;
#   	float P0(days31, hours, min10) ;
#   		P0:units = "hPa" ;
#   		P0:long_name = "MERGED Atmospheric air pressure" ;
#   		P0:standard_name = "air_pressure_at_sensor_level" ;
#   		P0:accuracy = "0.1" ;
#   		P0:ancillary_variables = "IP0" ;
#   		P0:cell_methods = "time: mean" ;
#   	float TA002(days31, hours, min10) ;
#   		TA002:units = "degC" ;
#   		TA002:long_name = "MERGED Air temperature at   2 m" ;
#   		TA002:standard_name = "air_temperature" ;
#   		TA002:accuracy = "0.1" ;
#   		TA002:ancillary_variables = "ITA002" ;
#   		TA002:cell_methods = "time: mean" ;
#   	float Q002(days31, hours, min10) ;
#   		Q002:units = "1e-3" ;
#   		Q002:long_name = "MERGED Specific humidity     at   2 m" ;
#   		Q002:ancillary_variables = "IQ002" ;
#   		Q002:cell_methods = "time: mean" ;
#   	float F010(days31, hours, min10) ;
#   		F010:units = "m s-1" ;
#   		F010:long_name = "MERGED Wind speed at  10 m" ;
#   		F010:standard_name = "wind_speed" ;
#   		F010:accuracy = "0.5" ;
#   		F010:ancillary_variables = "IF010" ;
#   		F010:cell_methods = "time: mean" ;
#   	float TA(days31, hours, min10, z) ;
#   		TA:units = "K" ;
#   		TA:long_name = "MERGED Air temperature" ;
#   		TA:standard_name = "air_temperature" ;
#   		TA:ancillary_variables = "ITA" ;
#   		TA:cell_methods = "time: mean" ;
#   	float D(days31, hours, min10, z) ;
#   		D:units = "degree" ;
#   		D:long_name = "MERGED Wind direction" ;
#   		D:standard_name = "wind_from_direction" ;
#   		D:ancillary_variables = "ID" ;
#   		D:cell_methods = "time: mean" ;
#   	float Q(days31, hours, min10, z) ;
#   		Q:units = "1e-3" ;
#   		Q:long_name = "MERGED Specific humidity" ;
#   		Q:ancillary_variables = "IQ" ;
#   		Q:cell_methods = "time: mean" ;
#   	float TD(days31, hours, min10, z) ;
#   		TD:units = "K" ;
#   		TD:long_name = "Dew point temperature from MERGED Spec. hum." ;
#   		TD:standard_name = "dew_point_temperature" ;
#   		TD:cell_methods = "time: mean" ;
#   	float F(days31, hours, min10, z) ;
#   		F:units = "m s-1" ;
#   		F:long_name = "MERGED Wind speed" ;
#   		F:standard_name = "wind_speed" ;
#   		F:ancillary_variables = "IF" ;
#   		F:cell_methods = "time: mean" ;
#   	double time(days31, hours, min10) ;
#   		time:timezone = "UTC" ;
#   		time:comment = "convert using datetime.fromtimestamp(var,pytz.utc)" ;
#
#   // group attributes:
#   		:month = 2014, 8 ;
#   } // group m2014_08
#
# group: m2014_09 {
#   variables:
#   	float H(days30, hours, min10) ;
#   		H:units = "W m-2" ;
#   		H:long_name = "MERGED Surface sensible heat flux" ;
#   		H:standard_name = "surface_upward_sensible_heat_flux" ;
#   		H:accuracy = "10%" ;
#   		H:ancillary_variables = "IH" ;
#   		H:cell_methods = "time: mean" ;
#   	float LE(days30, hours, min10) ;
#   		LE:units = "W m-2" ;
#   		LE:long_name = "MERGED Surface latent heat flux" ;
#   		LE:standard_name = "surface_upward_latent_heat_flux" ;
#   		LE:accuracy = "10%" ;
#   		LE:ancillary_variables = "ILE" ;
#   		LE:cell_methods = "time: mean" ;
#   	float UST(days30, hours, min10) ;
#   		UST:units = "m s-1" ;
#   		UST:long_name = "MERGED Friction velocity" ;
#   		UST:ancillary_variables = "IUST" ;
#   		UST:cell_methods = "time: mean" ;
#   	float P0(days30, hours, min10) ;
#   		P0:units = "hPa" ;
#   		P0:long_name = "MERGED Atmospheric air pressure" ;
#   		P0:standard_name = "air_pressure_at_sensor_level" ;
#   		P0:accuracy = "0.1" ;
#   		P0:ancillary_variables = "IP0" ;
#   		P0:cell_methods = "time: mean" ;
#   	float TA002(days30, hours, min10) ;
#   		TA002:units = "degC" ;
#   		TA002:long_name = "MERGED Air temperature at   2 m" ;
#   		TA002:standard_name = "air_temperature" ;
#   		TA002:accuracy = "0.1" ;
#   		TA002:ancillary_variables = "ITA002" ;
#   		TA002:cell_methods = "time: mean" ;
#   	float Q002(days30, hours, min10) ;
#   		Q002:units = "1e-3" ;
#   		Q002:long_name = "MERGED Specific humidity     at   2 m" ;
#   		Q002:ancillary_variables = "IQ002" ;
#   		Q002:cell_methods = "time: mean" ;
#   	float F010(days30, hours, min10) ;
#   		F010:units = "m s-1" ;
#   		F010:long_name = "MERGED Wind speed at  10 m" ;
#   		F010:standard_name = "wind_speed" ;
#   		F010:accuracy = "0.5" ;
#   		F010:ancillary_variables = "IF010" ;
#   		F010:cell_methods = "time: mean" ;
#   	float TA(days30, hours, min10, z) ;
#   		TA:units = "K" ;
#   		TA:long_name = "MERGED Air temperature" ;
#   		TA:standard_name = "air_temperature" ;
#   		TA:ancillary_variables = "ITA" ;
#   		TA:cell_methods = "time: mean" ;
#   	float D(days30, hours, min10, z) ;
#   		D:units = "degree" ;
#   		D:long_name = "MERGED Wind direction" ;
#   		D:standard_name = "wind_from_direction" ;
#   		D:ancillary_variables = "ID" ;
#   		D:cell_methods = "time: mean" ;
#   	float Q(days30, hours, min10, z) ;
#   		Q:units = "1e-3" ;
#   		Q:long_name = "MERGED Specific humidity" ;
#   		Q:ancillary_variables = "IQ" ;
#   		Q:cell_methods = "time: mean" ;
#   	float TD(days30, hours, min10, z) ;
#   		TD:units = "K" ;
#   		TD:long_name = "Dew point temperature from MERGED Spec. hum." ;
#   		TD:standard_name = "dew_point_temperature" ;
#   		TD:cell_methods = "time: mean" ;
#   	float F(days30, hours, min10, z) ;
#   		F:units = "m s-1" ;
#   		F:long_name = "MERGED Wind speed" ;
#   		F:standard_name = "wind_speed" ;
#   		F:ancillary_variables = "IF" ;
#   		F:cell_methods = "time: mean" ;
#   	double time(days30, hours, min10) ;
#   		time:timezone = "UTC" ;
#   		time:comment = "convert using datetime.fromtimestamp(var,pytz.utc)" ;
#
#   // group attributes:
#   		:month = 2014, 9 ;
#   } // group m2014_09
#
# group: m2014_10 {
#   variables:
#   	float H(days31, hours, min10) ;
#   		H:units = "W m-2" ;
#   		H:long_name = "MERGED Surface sensible heat flux" ;
#   		H:standard_name = "surface_upward_sensible_heat_flux" ;
#   		H:accuracy = "10%" ;
#   		H:ancillary_variables = "IH" ;
#   		H:cell_methods = "time: mean" ;
#   	float LE(days31, hours, min10) ;
#   		LE:units = "W m-2" ;
#   		LE:long_name = "MERGED Surface latent heat flux" ;
#   		LE:standard_name = "surface_upward_latent_heat_flux" ;
#   		LE:accuracy = "10%" ;
#   		LE:ancillary_variables = "ILE" ;
#   		LE:cell_methods = "time: mean" ;
#   	float UST(days31, hours, min10) ;
#   		UST:units = "m s-1" ;
#   		UST:long_name = "MERGED Friction velocity" ;
#   		UST:ancillary_variables = "IUST" ;
#   		UST:cell_methods = "time: mean" ;
#   	float P0(days31, hours, min10) ;
#   		P0:units = "hPa" ;
#   		P0:long_name = "MERGED Atmospheric air pressure" ;
#   		P0:standard_name = "air_pressure_at_sensor_level" ;
#   		P0:accuracy = "0.1" ;
#   		P0:ancillary_variables = "IP0" ;
#   		P0:cell_methods = "time: mean" ;
#   	float TA002(days31, hours, min10) ;
#   		TA002:units = "degC" ;
#   		TA002:long_name = "MERGED Air temperature at   2 m" ;
#   		TA002:standard_name = "air_temperature" ;
#   		TA002:accuracy = "0.1" ;
#   		TA002:ancillary_variables = "ITA002" ;
#   		TA002:cell_methods = "time: mean" ;
#   	float Q002(days31, hours, min10) ;
#   		Q002:units = "1e-3" ;
#   		Q002:long_name = "MERGED Specific humidity     at   2 m" ;
#   		Q002:ancillary_variables = "IQ002" ;
#   		Q002:cell_methods = "time: mean" ;
#   	float F010(days31, hours, min10) ;
#   		F010:units = "m s-1" ;
#   		F010:long_name = "MERGED Wind speed at  10 m" ;
#   		F010:standard_name = "wind_speed" ;
#   		F010:accuracy = "0.5" ;
#   		F010:ancillary_variables = "IF010" ;
#   		F010:cell_methods = "time: mean" ;
#   	float TA(days31, hours, min10, z) ;
#   		TA:units = "K" ;
#   		TA:long_name = "MERGED Air temperature" ;
#   		TA:standard_name = "air_temperature" ;
#   		TA:ancillary_variables = "ITA" ;
#   		TA:cell_methods = "time: mean" ;
#   	float D(days31, hours, min10, z) ;
#   		D:units = "degree" ;
#   		D:long_name = "MERGED Wind direction" ;
#   		D:standard_name = "wind_from_direction" ;
#   		D:ancillary_variables = "ID" ;
#   		D:cell_methods = "time: mean" ;
#   	float Q(days31, hours, min10, z) ;
#   		Q:units = "1e-3" ;
#   		Q:long_name = "MERGED Specific humidity" ;
#   		Q:ancillary_variables = "IQ" ;
#   		Q:cell_methods = "time: mean" ;
#   	float TD(days31, hours, min10, z) ;
#   		TD:units = "K" ;
#   		TD:long_name = "Dew point temperature from MERGED Spec. hum." ;
#   		TD:standard_name = "dew_point_temperature" ;
#   		TD:cell_methods = "time: mean" ;
#   	float F(days31, hours, min10, z) ;
#   		F:units = "m s-1" ;
#   		F:long_name = "MERGED Wind speed" ;
#   		F:standard_name = "wind_speed" ;
#   		F:ancillary_variables = "IF" ;
#   		F:cell_methods = "time: mean" ;
#   	double time(days31, hours, min10) ;
#   		time:timezone = "UTC" ;
#   		time:comment = "convert using datetime.fromtimestamp(var,pytz.utc)" ;
#
#   // group attributes:
#   		:month = 2014, 10 ;
#   } // group m2014_10
#
# group: m2014_11 {
#   variables:
#   	float H(days30, hours, min10) ;
#   		H:units = "W m-2" ;
#   		H:long_name = "MERGED Surface sensible heat flux" ;
#   		H:standard_name = "surface_upward_sensible_heat_flux" ;
#   		H:accuracy = "10%" ;
#   		H:ancillary_variables = "IH" ;
#   		H:cell_methods = "time: mean" ;
#   	float LE(days30, hours, min10) ;
#   		LE:units = "W m-2" ;
#   		LE:long_name = "MERGED Surface latent heat flux" ;
#   		LE:standard_name = "surface_upward_latent_heat_flux" ;
#   		LE:accuracy = "10%" ;
#   		LE:ancillary_variables = "ILE" ;
#   		LE:cell_methods = "time: mean" ;
#   	float UST(days30, hours, min10) ;
#   		UST:units = "m s-1" ;
#   		UST:long_name = "MERGED Friction velocity" ;
#   		UST:ancillary_variables = "IUST" ;
#   		UST:cell_methods = "time: mean" ;
#   	float P0(days30, hours, min10) ;
#   		P0:units = "hPa" ;
#   		P0:long_name = "MERGED Atmospheric air pressure" ;
#   		P0:standard_name = "air_pressure_at_sensor_level" ;
#   		P0:accuracy = "0.1" ;
#   		P0:ancillary_variables = "IP0" ;
#   		P0:cell_methods = "time: mean" ;
#   	float TA002(days30, hours, min10) ;
#   		TA002:units = "degC" ;
#   		TA002:long_name = "MERGED Air temperature at   2 m" ;
#   		TA002:standard_name = "air_temperature" ;
#   		TA002:accuracy = "0.1" ;
#   		TA002:ancillary_variables = "ITA002" ;
#   		TA002:cell_methods = "time: mean" ;
#   	float Q002(days30, hours, min10) ;
#   		Q002:units = "1e-3" ;
#   		Q002:long_name = "MERGED Specific humidity     at   2 m" ;
#   		Q002:ancillary_variables = "IQ002" ;
#   		Q002:cell_methods = "time: mean" ;
#   	float F010(days30, hours, min10) ;
#   		F010:units = "m s-1" ;
#   		F010:long_name = "MERGED Wind speed at  10 m" ;
#   		F010:standard_name = "wind_speed" ;
#   		F010:accuracy = "0.5" ;
#   		F010:ancillary_variables = "IF010" ;
#   		F010:cell_methods = "time: mean" ;
#   	float TA(days30, hours, min10, z) ;
#   		TA:units = "K" ;
#   		TA:long_name = "MERGED Air temperature" ;
#   		TA:standard_name = "air_temperature" ;
#   		TA:ancillary_variables = "ITA" ;
#   		TA:cell_methods = "time: mean" ;
#   	float D(days30, hours, min10, z) ;
#   		D:units = "degree" ;
#   		D:long_name = "MERGED Wind direction" ;
#   		D:standard_name = "wind_from_direction" ;
#   		D:ancillary_variables = "ID" ;
#   		D:cell_methods = "time: mean" ;
#   	float Q(days30, hours, min10, z) ;
#   		Q:units = "1e-3" ;
#   		Q:long_name = "MERGED Specific humidity" ;
#   		Q:ancillary_variables = "IQ" ;
#   		Q:cell_methods = "time: mean" ;
#   	float TD(days30, hours, min10, z) ;
#   		TD:units = "K" ;
#   		TD:long_name = "Dew point temperature from MERGED Spec. hum." ;
#   		TD:standard_name = "dew_point_temperature" ;
#   		TD:cell_methods = "time: mean" ;
#   	float F(days30, hours, min10, z) ;
#   		F:units = "m s-1" ;
#   		F:long_name = "MERGED Wind speed" ;
#   		F:standard_name = "wind_speed" ;
#   		F:ancillary_variables = "IF" ;
#   		F:cell_methods = "time: mean" ;
#   	double time(days30, hours, min10) ;
#   		time:timezone = "UTC" ;
#   		time:comment = "convert using datetime.fromtimestamp(var,pytz.utc)" ;
#
#   // group attributes:
#   		:month = 2014, 11 ;
#   } // group m2014_11
#
# group: m2014_12 {
#   variables:
#   	float H(days31, hours, min10) ;
#   		H:units = "W m-2" ;
#   		H:long_name = "MERGED Surface sensible heat flux" ;
#   		H:standard_name = "surface_upward_sensible_heat_flux" ;
#   		H:accuracy = "10%" ;
#   		H:ancillary_variables = "IH" ;
#   		H:cell_methods = "time: mean" ;
#   	float LE(days31, hours, min10) ;
#   		LE:units = "W m-2" ;
#   		LE:long_name = "MERGED Surface latent heat flux" ;
#   		LE:standard_name = "surface_upward_latent_heat_flux" ;
#   		LE:accuracy = "10%" ;
#   		LE:ancillary_variables = "ILE" ;
#   		LE:cell_methods = "time: mean" ;
#   	float UST(days31, hours, min10) ;
#   		UST:units = "m s-1" ;
#   		UST:long_name = "MERGED Friction velocity" ;
#   		UST:ancillary_variables = "IUST" ;
#   		UST:cell_methods = "time: mean" ;
#   	float P0(days31, hours, min10) ;
#   		P0:units = "hPa" ;
#   		P0:long_name = "MERGED Atmospheric air pressure" ;
#   		P0:standard_name = "air_pressure_at_sensor_level" ;
#   		P0:accuracy = "0.1" ;
#   		P0:ancillary_variables = "IP0" ;
#   		P0:cell_methods = "time: mean" ;
#   	float TA002(days31, hours, min10) ;
#   		TA002:units = "degC" ;
#   		TA002:long_name = "MERGED Air temperature at   2 m" ;
#   		TA002:standard_name = "air_temperature" ;
#   		TA002:accuracy = "0.1" ;
#   		TA002:ancillary_variables = "ITA002" ;
#   		TA002:cell_methods = "time: mean" ;
#   	float Q002(days31, hours, min10) ;
#   		Q002:units = "1e-3" ;
#   		Q002:long_name = "MERGED Specific humidity     at   2 m" ;
#   		Q002:ancillary_variables = "IQ002" ;
#   		Q002:cell_methods = "time: mean" ;
#   	float F010(days31, hours, min10) ;
#   		F010:units = "m s-1" ;
#   		F010:long_name = "MERGED Wind speed at  10 m" ;
#   		F010:standard_name = "wind_speed" ;
#   		F010:accuracy = "0.5" ;
#   		F010:ancillary_variables = "IF010" ;
#   		F010:cell_methods = "time: mean" ;
#   	float TA(days31, hours, min10, z) ;
#   		TA:units = "K" ;
#   		TA:long_name = "MERGED Air temperature" ;
#   		TA:standard_name = "air_temperature" ;
#   		TA:ancillary_variables = "ITA" ;
#   		TA:cell_methods = "time: mean" ;
#   	float D(days31, hours, min10, z) ;
#   		D:units = "degree" ;
#   		D:long_name = "MERGED Wind direction" ;
#   		D:standard_name = "wind_from_direction" ;
#   		D:ancillary_variables = "ID" ;
#   		D:cell_methods = "time: mean" ;
#   	float Q(days31, hours, min10, z) ;
#   		Q:units = "1e-3" ;
#   		Q:long_name = "MERGED Specific humidity" ;
#   		Q:ancillary_variables = "IQ" ;
#   		Q:cell_methods = "time: mean" ;
#   	float TD(days31, hours, min10, z) ;
#   		TD:units = "K" ;
#   		TD:long_name = "Dew point temperature from MERGED Spec. hum." ;
#   		TD:standard_name = "dew_point_temperature" ;
#   		TD:cell_methods = "time: mean" ;
#   	float F(days31, hours, min10, z) ;
#   		F:units = "m s-1" ;
#   		F:long_name = "MERGED Wind speed" ;
#   		F:standard_name = "wind_speed" ;
#   		F:ancillary_variables = "IF" ;
#   		F:cell_methods = "time: mean" ;
#   	double time(days31, hours, min10) ;
#   		time:timezone = "UTC" ;
#   		time:comment = "convert using datetime.fromtimestamp(var,pytz.utc)" ;
#
#   // group attributes:
#   		:month = 2014, 12 ;
#   } // group m2014_12
# }
